# %% [markdown]
# # 作業一  #

# %% [markdown]
# ## 選擇的Dataset: Google Play Store Apps ##
# **[Google play store apps dataset link](https://www.kaggle.com/lava18/google-play-store-apps)**
#
# - 為何選擇此Dataset?
# 這組資料記錄了所GooglePlayStore的相關資訊，包括:13種關於App的資料，如，App名稱、類別、點閱人次、下載人次、
# 上架日期及用戶評價等等。這樣的Dataset，他能提供App開發者、經營管理等相關人員進行市場分析，藉以優化經營策略、提升獲利。
#
# **例如: 下載人次高的、點閱人次高的Apps是否有和共通點，名稱上共通點或者類別上共通點，藉由分析這樣的資訊，即可了解使用者偏好，
# 針對偏好去設計App特性以提高人氣。**
#
#
# - 資料來源?
# 這組資料來自印度一位軟體工程師，Lavanya Gupta，對Google Play stores以程式語言進行網路爬取所獲得。
#
#
# - 蒐集來的資料型式?
# 蒐集來的資料可能是ㄧ些字串(例如包括各國語言的用戶回饋)或者數字(例如用戶給分或累計下載人次)，分門別類後組成關於
# 這1萬個Apps相關資訊的csv file。
#
#
# - 如何分析資料?
# 由於資料是各種不同Apps的特性，因此可藉由統計方法來評估、比較相同App特性之間的相關性，或者不同App同特性之間的相關性;
# 也可藉由繪製趨勢圖來分析那些特性對於一個App的成敗有相關性。

# %% [markdown]
# # 作業二 #

# %% [markdown]
# ## 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：##
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# 若我經營一個自由載客車隊，並想透過數據分析提升業績：
# 提升業績，代表整個車隊的營收增加的情況，除了較無改變空間的營業成本之外，增加載客率也是個方向。
# 假設使用手機App作為經營管理整個車隊接客的平台，就可透過網路的便利和即時性去吸引乘客使用，增加載客率。
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# 以上述假設的例子來說，可透過乘客註冊車隊App來獲取一些基本乘客資訊，也可來自乘客對於服務的回饋。
#
# 3. 蒐集而來的資料型態為何
# 可能為數字或字串，彙整成的表格。
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# 假設為多了App來經營會提升載客率以及業績，那就可分析、統計App加入前後的業績可粗略得知。

# %% [markdown]
# # 作業三

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# MSE function #

def mean_squared_error(yi, yp):
    
    MSE = sum((yi - yp)**2) / len(yi) 
    
    return MSE

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# calculate MSE and print result #
MSE = mean_squared_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
# Out:
# The Mean squared error is 222.631
