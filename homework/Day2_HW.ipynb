# %%
import os
import pandas as pd
import numpy as np

# %%
os.chdir(r"C:\Users\Wendy\Documents\GitHub\2nd-ML100Days\data")
app_train = pd.read_csv("application_train.csv")

# %% [markdown]
# # 了解資料(Dataframe)的基本資訊

# %%
# shape of app_train dataframe: (row, column)
app_train.shape
# Out:
# (307511, 122)

# %%
# print top n row
n = 10
app_train.head(n)
# Out:
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0      100002       1         Cash loans           M            N
# 1      100003       0         Cash loans           F            N
# 2      100004       0    Revolving loans           M            Y
# 3      100006       0         Cash loans           F            N
# 4      100007       0         Cash loans           M            N
# 5      100008       0         Cash loans           M            N
# 6      100009       0         Cash loans           F            Y
# 7      100010       0         Cash loans           M            Y
# 8      100011       0         Cash loans           F            N
# 9      100012       0    Revolving loans           M            N
#
#   FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 0               Y             0          202500.0    406597.5      24700.5
# 1               N             0          270000.0   1293502.5      35698.5
# ...

# %%
# get column name (tolist() to get as a list)
app_train.columns
# Out:
# Index(['SK_ID_CURR', 'TARGET', 'NAME_CONTRACT_TYPE', 'CODE_GENDER',
#        'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'CNT_CHILDREN', 'AMT_INCOME_TOTAL',
#        'AMT_CREDIT', 'AMT_ANNUITY',
#        ...
#        'FLAG_DOCUMENT_18', 'FLAG_DOCUMENT_19', 'FLAG_DOCUMENT_20',
#        'FLAG_DOCUMENT_21', 'AMT_REQ_CREDIT_BUREAU_HOUR',
#        'AMT_REQ_CREDIT_BUREAU_DAY', 'AMT_REQ_CREDIT_BUREAU_WEEK',
#        'AMT_REQ_CREDIT_BUREAU_MON', 'AMT_REQ_CREDIT_BUREAU_QRT',
#        'AMT_REQ_CREDIT_BUREAU_YEAR'],
#       dtype='object', length=122)

# %%
# get index name
app_train.index
# Out:
# RangeIndex(start=0, stop=307511, step=1)

# %%
# get specific column by name (1)
app_train["CODE_GENDER"]
# Out:
# 0         M
# 1         F
# 2         M
# 3         F
# 4         M
# 5         M
# 6         F
# 7         M
# 8         F
# 9         M
# 10        F
# 11        F
# 12        F
# 13        M
# 14        F
# 15        M
# 16        M
# 17        F
# 18        F
# 19        F
# 20        M
# 21        F
# 22        F
# 23        F
# 24        M
# 25        F
# 26        F
# 27        M
# 28        M
# 29        M
#          ..
# 307481    M
# 307482    F
# 307483    F
# 307484    F
# 307485    F
# 307486    F
# 307487    M
# 307488    F
# 307489    F
# 307490    M
# 307491    M
# 307492    M
# 307493    F
# 307494    M
# 307495    M
# 307496    F
# 307497    F
# 307498    M
# 307499    F
# 307500    F
# 307501    F
# 307502    F
# 307503    F
# 307504    F
# 307505    F
# 307506    M
# 307507    F
# 307508    F
# 307509    F
# 307510    F
# Name: CODE_GENDER, Length: 307511, dtype: object

# %%
# get specific column by name (2)
app_train.loc[0:3, "TARGET":"CODE_GENDER"] # select a range of columns
app_train.loc[0:3, ["TARGET","CODE_GENDER"]] # select a specific columns by name list
# Out:
#    TARGET NAME_CONTRACT_TYPE CODE_GENDER
# 0       1         Cash loans           M
# 1       0         Cash loans           F
# 2       0    Revolving loans           M
# 3       0         Cash loans           F

# %%
# get specific portion of data: dataframe.iloc[row number, column number]
#app_train.iloc[0:3, [1,3]] # select a specific columns by col number list
app_train.iloc[0:3, 1:4] # select a range of columns by col number range
# Out:
#    TARGET NAME_CONTRACT_TYPE CODE_GENDER
# 0       1         Cash loans           M
# 1       0         Cash loans           F
# 2       0    Revolving loans           M

# %%
# drop by index
app_train.drop([0,3]).head(5)
# Out:
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 1      100003       0         Cash loans           F            N
# 2      100004       0    Revolving loans           M            Y
# 4      100007       0         Cash loans           M            N
# 5      100008       0         Cash loans           M            N
# 6      100009       0         Cash loans           F            Y
#
#   FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 1               N             0          270000.0   1293502.5      35698.5
# 2               Y             0           67500.0    135000.0       6750.0
# 4               Y             0          121500.0    513000.0      21865.5
# 5               Y             0           99000.0    490495.5      27517.5
# 6               Y             1          171000.0   1560726.0      41301.0
#
#               ...              FLAG_DOCUMENT_18 FLAG_DOCUMENT_19  \
# ...
